# %%
#  data analysis

import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_json('/home/csgrad/akumar58/Projects/parspec/train.json')
df.head()
# Out:
#       id                                           doc_text  label
# 0  P-695  \n\nPAGECi riserviamo il diritto di modificare...      1
# 1  P-913  \n\nPAGESunStat® ConnectPlus™\nThermostat Wi-F...      0
# 2  P-656  \n\nPAGE176\nEMERGI-LITE CENTR AL & INVERTER S...      0
# 3  P-951  \n\nPAGEØ 4.4 mm\n9\n7\nVIEW A\nCROSS SECTION\...      0
# 4  P-410  \n\nPAGE425 N Robertson Blvd\nLos Angeles, Cal...      1

# %%
df.isna().sum()
# Out:
# id          0
# doc_text    0
# label       0
# dtype: int64

# %%
df.shape
# Out:
# (874, 3)

# %%
#  checking class imbalance in train set
df['label'].value_counts(normalize = False).plot.bar()
# Out:
# <Axes: xlabel='label'>

# %%
import matplotlib.pyplot as plt

# Confusion matrix data
conf_matrix = [[51, 9],
               [0, 20]]

# Plotting the confusion matrix
fig, ax = plt.subplots(figsize=(4, 4))

# Display the confusion matrix as a heatmap
cax = ax.matshow(conf_matrix, cmap='Blues')

# Add labels to the plot
plt.xticks(range(len(conf_matrix[0])), ['Lighting', 'Not Lighting'])
plt.yticks(range(len(conf_matrix)), ['Lighting', 'Not Lighting'])
# Out:
# ([<matplotlib.axis.YTick at 0x7f54683a1990>,
# ...
#  [Text(0, 0, 'Lighting'), Text(0, 1, 'Not Lighting')])

# %%
import matplotlib.pyplot as plt

# Confusion matrix data
conf_matrix = [[51, 9],
               [0, 20]]

# Plotting the confusion matrix
fig, ax = plt.subplots(figsize=(4, 4))

# Display the confusion matrix as a heatmap
cax = ax.matshow(conf_matrix, cmap='Blues')

# Add labels to the plot
plt.xticks(range(len(conf_matrix[0])), ['Lighting', 'Not Lighting'])
plt.yticks(range(len(conf_matrix)), ['Lighting', 'Not Lighting'])

# Add text annotations
for i in range(len(conf_matrix)):
    for j in range(len(conf_matrix[0])):
        ax.text(j, i, str(conf_matrix[i][j]), ha='center', va='center', fontsize=14, color='black')

# Add colorbar
cbar = plt.colorbar(cax)

# Add labels and title
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')

plt.show()
